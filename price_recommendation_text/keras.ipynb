# %%
# coding: utf-8

# mainly forking from notebook
# https://www.kaggle.com/johnfarrell/simple-rnn-with-keras-script

# ADDED
# 5x scaled test set
# category name embedding
# some small changes like lr, decay, batch_size~

import os
import gc
import time
start_time = time.time()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.ERROR)
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

pd.set_option('display.max_colwidth', 500)

# %%
train = pd.read_csv('data/train.tsv', sep='\t')
test = pd.read_csv('data/test.tsv', sep='\t')

train['target'] = np.log1p(train['price'])


print(train.shape)
print('5 folds scaling the test_df')
print(test.shape)
test_len = test.shape[0]
def simulate_test(test):
    if test.shape[0] < 800000:
        indices = np.random.choice(test.index.values, 2800000)
        test_ = pd.concat([test, test.iloc[indices]], axis=0)
        return test_.copy()
    else:
        return test
test = simulate_test(test)
print('new shape ', test.shape)
print('[{}] Finished scaling test set...'.format(time.time() - start_time))
# Out:
# (1482535, 9)
# 5 folds scaling the test_df
# (693359, 7)
# new shape  (3493359, 7)
# [12.549781084060669] Finished scaling test set...

# %%
#HANDLE MISSING VALUES
print("Handling missing values...")
def handle_missing(dataset):
    dataset.category_name.fillna(value="missing", inplace=True)
    dataset.brand_name.fillna(value="missing", inplace=True)
    dataset.item_description.fillna(value="missing", inplace=True)
    return (dataset)

train = handle_missing(train)
test = handle_missing(test)
print(train.shape)
print(test.shape)

print('[{}] Finished handling missing data...'.format(time.time() - start_time))
# Out:
# Handling missing values...
# (1482535, 9)
# (3493359, 7)
# [13.26332139968872] Finished handling missing data...

# %%
#PROCESS CATEGORICAL DATA
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
print("Handling categorical variables...")
le = LabelEncoder()

le.fit(np.hstack([train.category_name, test.category_name]))
train['category'] = le.transform(train.category_name)
test['category'] = le.transform(test.category_name)

le.fit(np.hstack([train.brand_name, test.brand_name]))
train['brand'] = le.transform(train.brand_name)
test['brand'] = le.transform(test.brand_name)
del le, train['brand_name'], test['brand_name']

print('[{}] Finished PROCESSING CATEGORICAL DATA...'.format(time.time() - start_time))
train.head(3)
# Out:
# Handling categorical variables...
# [30.39798402786255] Finished PROCESSING CATEGORICAL DATA...
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
#
#                                         category_name  price  shipping  \
# 0                                   Men/Tops/T-shirts   10.0         1
# 1  Electronics/Computers & Tablets/Components & Parts   52.0         0
# 2                         Women/Tops & Blouses/Blouse   10.0         1
#
#                                                                                                                                                                                item_description  \
# 0                                                                                                                                                                            No description yet
# 1  This keyboard is in great condition and works like it came out of the box. All of the ports are tested and work perfectly. The lights are customizable via the Razer Synapse app on your PC.
# 2                                                                  Adorable top with a hint of lace and a key hole in the back! The pale pink is a 1X, and I also have a 3X available in white!
#
#      target  category  brand
# 0  2.397895       829   5265
# 1  3.970292        86   3889
# 2  2.397895      1277   4588

# %%
train.head(100)
# Out:
#     train_id                                      name  item_condition_id  \
# 0          0       MLB Cincinnati Reds T Shirt Size XL                  3
# 1          1          Razer BlackWidow Chroma Keyboard                  3
# 2          2                            AVA-VIV Blouse                  1
# 3          3                     Leather Horse Statues                  1
# 4          4                      24K GOLD plated rose                  1
# 5          5          Bundled items requested for Ruie                  3
# 6          6        Acacia pacific tides santorini top                  3
# 7          7      Girls cheer and tumbling bundle of 7                  3
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                                        5 Mascaras Loreal Covergirl Rimmel Maybelline
# 83                                                                            Eyebrows Essential Kit   Everything you need to create perfect eyebrows packed in one convenient package. With easy to follow directions, it enables you to have the natural looking brows without harsh line that enhance your features. Brows  Essential Kit consists of : 1 Eyebrow Powder 3 Eyebrow stencils in thin, natural and thick, 1 Eyebrow brush applicator used to apply the eyebrow powder precisely to the desired effect.
# 84                                                                                                                                                                                                                                                                                                                                                                                                                                                Extra large shirt with purple beaded flower design. Size extra large.
# 85                                                                                                                                                                                                                                              Hot pink/reddish sheet set from Victoria's Secret PINK store. In good condition, some fading from washing but fully intact. Includes flat sheet and two pillow cases, no fitted sheet! Design is white hearts with light pink cheetah print trim. Fits queen sized bed!
# 86                                                                                                                                           This boxed set of 12 DVD’s includes the Fitness Guide, Meal Plan, and Rotational Calendar. The DVD’s include: Fire Up, Ignite, Launch, Rise, Amplify, Escalate, Conquer, Triumph, Zenith, and Apex. Includes BONUS DVD Opus and the Cast & Moves Disc. Original dvds sealed in box. Ships out within 24 hours Ignore: insanity p90x work out workout abs muscles bodyshred
# 87                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Used but still a great play item.
# 88                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   I have 2 available
# 89                                                                                                                                                                                                                                                                                                                                                                                                          Size 6Y. High tops. Super light. In good condition. Worn for 1 basketball season. Don't fit my sin anymore.
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   No description yet
# 91                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Good used condition. Ask about bundling to save.
# 92                                                                                                                                                                                                                                                                                                                                                                                                           Distressed with holes. Great shape well taken care of! Fits a size 11, perfect for spring summer and fall!
# 93                                                                                                                                                                                                                                                                                                                                                                                                                                       Size M (8), cuffs show wear and letters are not peeling off it came like that.
# 94                                                                                                                                                                                                                                                                                                                                                                                                                                                                                BNIP VHTF! HOTTEST toy of the season!
# 95                                                                                                                                                                                                                                                                                                                                            BabyGap canvas army green Gently loved, lots of life left No holes Throw in the wash & hang dry, or wipe them clean. Girl or boy, my son wore these with Khakis to church
# 96                                                Bought off Groupon and they charged me for 2, sent 2, and they won't return one even though it was a system error! It's still new and completely sealed. The second picture shows everything that's in it and the regular cost. It also comes with a how-to DVD. I ordered the "medium shade" as well. Comes with 4 different shades "to find your perfect match", a face primer, a brightening color, and blush. You can buy different shades off their website too.
# 97                                                                                                                                                                                                                                                                                                                        Bling Mickey ear case!! Just used one for a Disney trip! Received many compliments!! Bling ears! Super cute! 3 stones missing to be exact but barely noticeable :) comes with strap for neck!
# 98                                                                                                                                                                                                                                                                                                                                                                                                                                   Rose gold bezel and crown Engraved logo Red and green signature band Unisex No box
# 99                                                                                                                                                                                                                                                                                                              Watercolor Inspire crop. No pilling or stickiness whatsoever. Some of the pink has bled into the white part of the waistband, not noticeable from a distance. 22" inseam. Rip tag still intact, size 6.
#
#       target  category  brand
# 0   2.397895       829   5265
# 1   3.970292        86   3889
# 2   2.397895      1277   4588
# 3   3.583519       503   5265
# 4   3.806662      1204   5265
# 5   4.094345      1216   5265
# 6   4.174387      1276     84
# 7   1.945910       908   4341
# 8   2.995732       908   3337
# 9   2.197225      1045   5265
# 10  2.197225        27   4325
# 11  3.555348        11   4953
# 12  2.833213      1184   5278
# 13  1.609438       898   4162
# 14  3.784190      1227   4841
# 15  2.484907        31   4592
# 16  1.945910        26   5053
# 17  3.401197       621   5265
# 18  3.258097        29   4747
# 19  3.332205      1277    283
# 20  2.639057      1284   4762
# 21  3.044522      1166   4953
# 22  5.958425        81   4121
# 23  2.197225        82   5265
# 24  2.397895      1283   1646
# 25  4.204693       780    140
# 26  2.639057        79    293
# 27  3.218876      1160   2850
# 28  1.791759      1275   1646
# 29  2.833213      1190   2130
# ..       ...       ...    ...
# 70  4.127134      1226    109
# 71  1.609438      1204   5265
# 72  3.583519       504   3375
# 73  2.708050       580   5265
# 74  3.295837       523   3859
# 75  2.564949       707   2791
# 76  2.890372      1276   5265
# 77  2.995732       507   5265
# 78  2.302585       829   5265
# 79  2.708050       645   4186
# 80  2.833213      1215   3213
# 81  2.708050        27   4212
# 82  2.302585        26   5265
# 83  1.945910        26   5265
# 84  2.397895      1283   5265
# 85  2.944439       454   5265
# 86  3.688879       917   5265
# 87  3.555348       708   3074
# 88  1.386294      1149   3715
# 89  3.367296       577   3337
# 90  2.079442       554   4588
# 91  2.397895       112   3349
# 92  2.833213      1190   4277
# 93  2.397895       924   5265
# 94  5.017280       709   4400
# 95  2.302585       654   1858
# 96  4.406719        27   5265
# 97  2.302585        79   5265
# 98  3.912023       770   5265
# 99  3.806662      1160   2872
#
# [100 rows x 10 columns]

# %%
train = train[train.item_description != 'No description yet'].copy()

# %%
#PROCESS TEXT: RAW
print("Text to seq process...")
print("   Fitting tokenizer...")
from keras.preprocessing.text import Tokenizer

raw_text = np.hstack([train.category_name.str.lower(), 
                      train.item_description.str.lower(), 
                      train.name.str.lower()])

tok_raw = Tokenizer()
tok_raw.fit_on_texts(raw_text)
print("   Transforming text to seq...")
train["seq_category_name"] = tok_raw.texts_to_sequences(train.category_name.str.lower())
test["seq_category_name"] = tok_raw.texts_to_sequences(test.category_name.str.lower())
train["seq_item_description"] = tok_raw.texts_to_sequences(train.item_description.str.lower())
test["seq_item_description"] = tok_raw.texts_to_sequences(test.item_description.str.lower())
train["seq_name"] = tok_raw.texts_to_sequences(train.name.str.lower())
test["seq_name"] = tok_raw.texts_to_sequences(test.name.str.lower())
train.head(3)

print('[{}] Finished PROCESSING TEXT DATA...'.format(time.time() - start_time))
# Out:
# Text to seq process...
#    Fitting tokenizer...
# Using TensorFlow backend.
#    Transforming text to seq...
# [281.5643377304077] Finished PROCESSING TEXT DATA...

# %%
tok_raw.word_index
# Out:
# {'thymes': 68216,
#  'evision': 195898,
#  'shakillyia': 217715,
#  'carrillo': 226950,
#  'moomin': 57720,
#  'chandon': 115122,
#  'fixodent': 228979,
#  'slubknit': 176586,
#  'lvu3': 254140,
#  'scalebound': 196545,
#  'sqeezey': 214698,
#  'ysing': 181225,
#  'borderlands': 14281,
#  'fairmoor': 142639,
#  'greeklife': 161282,
#  'terminators': 91359,
#  'merdonl': 157350,
#  '743a': 150591,
#  'ninetendogs': 203486,
#  'kharki': 222096,
#  'bejeweled': 17311,
#  'atomized': 166494,
#  'zullala': 103554,
#  'cassandra': 16693,
#  'fledgling': 195911,
#  '\xa08': 56441,
#  'ntt10': 109003,
#  'bolted': 89617,
#  '30x33': 32706,
#  'bellamia': 236825,
#  "5''l": 88529,
#  '“graphite”': 229013,
#  '3349': 159978,
#  'urbandecayvintage': 124022,
#  'sturdiness': 37981,
#  'ct5113': 146573,
#  'letti': 194247,
#  'iridescence': 24922,
#  'strappie': 197443,
#  'w1233': 212405,
#  'miglin': 86908,
#  'color\xa0led': 175480,
#  'faberge': 53213,
#  'manucure': 74369,
#  '•locks': 19594,
#  'kar': 48242,
#  'britch': 181077,
#  'hollywoodtlc': 214433,
#  'wach': 54799,
#  'legendofthefall': 125598,
#  'colleged': 193281,
#  'ina': 37521,
#  'candiedunicornlove': 66863,
#  'estolberg22': 239434,
#  'oreo': 8349,
#  'barkcloth': 112286,
#  'coins': 3947,
#  'kayelya': 217552,
#  'eco': 4837,
#  '4chenora': 226971,
#  'phobic': 22603,
#  'sp70': 126123,
#  'shibe': 238618,
#  'haos': 146206,
#  'agent\xa0': 200420,
#  'mia’s': 148601,
#  'sugilite': 47791,
#  'by1': 184148,
#  'sidepockets': 179514,
#  'boulevart': 228837,
#  'buffy♡': 227967,
#  'angelik': 75449,
#  '9427': 105125,
#  '‼️scent': 171653,
#  'mudhoneyinc': 223414,
#  'sliponshoes': 148916,
#  'tilted': 21058,
#  'queen2': 245505,
#  "buddha's": 102233,
#  "gwen's": 98614,
#  '755m': 134798,
#  'kp09': 94890,
#  'glittr': 120370,
#  'hangouts': 48867,
#  'makeupbuys': 117837,
#  'tourmaline': 5956,
#  'baseus': 65510,
#  'lightsworn': 44905,
#  '65l': 100527,
#  'price⭐️yes': 40621,
#  'jasmine\xa0': 139049,
#  'stuff❤️❤️☺️☺️': 187723,
#  'iprincessinicole': 135033,
#  'eyecloths': 174641,
#  "'mix": 224392,
#  'patric': 131740,
#  'mspufob': 109709,
#  'pylon': 118743,
#  '➡️free': 27221,
#  'strowman': 118129,
#  '•pet': 10398,
#  "bowman's": 32081,
#  'clothesline': 24762,
#  'applciations': 186185,
#  '》free': 24586,
#  'cedars': 180027,
#  'rhiana': 231631,
#  'zb': 60782,
#  'fang': 12745,
#  'eliana': 110335,
#  'synthetica': 57840,
#  'circumference68': 182544,
#  'protectors✨✨✨': 252786,
#  'intamites': 225753,
#  'home☻': 75340,
#  'subervise': 124795,
#  'stretchtop': 212931,
#  'gruen': 40033,
#  'issuggested': 123370,
#  '5000pcs': 207397,
#  'wrng': 161581,
#  'wlru1958': 212219,
#  'ᗷᗩᖇᑎ': 252804,
#  'sheniah': 227598,
#  'geobra': 141772,
#  'sublim': 85075,
#  "sanuk's": 47858,
#  'mb22': 78224,
#  '◾️inseam': 42929,
#  '⚡️brand': 26671,
#  'fabric—durable': 130004,
#  'coverlets': 20515,
#  '⚡10': 97589,
#  'rondinella': 105830,
#  'gemstone': 2683,
#  '\u200b\u200b2007': 153344,
#  'quach': 221777,
#  '•44': 130671,
#  'chesnutskirt': 209476,
#  '⠀⠀⊗⊗⊗price': 204656,
#  'craftsmanship': 9916,
#  'lisaandra': 184491,
#  'liitle': 66084,
#  "ss16'": 120018,
#  'marinecorps': 204749,
#  'kthirteen': 230148,
#  'irritatingallergy': 168253,
#  'earings': 8688,
#  'steet': 71130,
#  'vlll': 68068,
#  'etchings': 31755,
#  'thisiscle': 123575,
#  'cogenderneutral': 171359,
#  'innact': 91282,
#  'colores': 22401,
#  'tooo': 40122,
#  'chocked': 40092,
#  'mls38': 212356,
#  'cultfavorite': 158444,
#  'charc': 86603,
#  'onies': 35888,
#  'kuool': 68015,
#  'fabregas': 241410,
#  'dying': 10115,
#  'lottle': 109741,
#  'legumes': 196103,
#  'adame': 230499,
#  '5mm）': 149502,
#  '•alice': 210253,
#  'tommygirl': 76814,
#  'a5638w': 116835,
#  'timecapsule': 247606,
#  'tooling': 52114,
#  'shader': 8061,
#  '68”': 201799,
#  'carcinogen': 64674,
#  'galaxy8': 220037,
#  'hdm165dq': 193237,
#  '22free': 210183,
#  'neatly': 9468,
#  'petty': 16696,
#  '✖️no': 12947,
#  "sandry's": 207052,
#  '▪waist': 52841,
#  '▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼': 39102,
#  "proactive's": 183275,
#  'alextan': 216003,
#  'straps⚡️': 131977,
#  'qasa': 118619,
#  'cici': 32043,
#  "'mango": 188746,
#  'tackling': 64767,
#  "'350": 127138,
#  'breaths': 38432,
#  'mist': 929,
#  'kronk': 84228,
#  'fucia': 72957,
#  'bundle⭐️': 62741,
#  'zubata': 252286,
#  'white✔✔': 113039,
#  'godismyall': 232413,
#  'slim3ydeco': 67718,
#  'dunomes': 200091,
#  'details\u2028': 94589,
#  'a1700025': 132172,
#  'artisan™': 131152,
#  'pecks': 36183,
#  "✨'i": 251677,
#  'goosedown': 45594,
#  'g530az': 121967,
#  '3800': 50657,
#  'clubbin': 159254,
#  'proganix': 54167,
#  'tennisshoes': 97636,
#  'case❤️': 62205,
#  'polarn': 213902,
#  'compatability': 26931,
#  'humans': 13992,
#  '10nike': 230992,
#  'verrryyyyy': 172204,
#  'pes': 41181,
#  'equivilant': 102217,
#  'agratzl': 119880,
#  'commercials': 54464,
#  '•bows': 196048,
#  '359229064489299': 181897,
#  'marsbar': 117245,
#  'wp460011': 189302,
#  'cef': 122876,
#  'sweetdrops': 86116,
#  '\xa0approximate': 78614,
#  'bullymomma325': 99988,
#  'withfor': 229595,
#  '6shades': 92177,
#  '❤challenge': 182642,
#  'addair': 185658,
#  'cable\xa0not': 52953,
#  'ritogo': 117064,
#  'j6910cdw': 176742,
#  'sunbay': 111466,
#  'thin': 1110,
#  'deap': 42252,
#  'suiting': 32883,
#  'am2': 85202,
#  '●mesh': 105315,
#  '•••●●♡●●♡♡●☆●♡♡●●♡●●•••': 144405,
#  'speedriod': 226102,
#  'ningun': 177199,
#  'panttop': 243347,
#  '♦️brand': 31226,
#  'espanola': 123865,
#  'crillan': 251806,
#  'loost': 133630,
#  '71214': 163593,
#  'foamy': 20332,
#  'jan25': 118945,
#  'ple': 39725,
#  'smartsoap': 63370,
#  'spirited': 12499,
#  'copperhead': 162495,
#  'sparkleshoes': 191755,
#  'fireside': 11209,
#  'suffocation': 45727,
#  'choker♡': 81013,
#  'sterilizes': 57156,
#  'samsungs': 15455,
#  'hyplar': 93062,
#  'statuettes': 109661,
#  'ritz': 28966,
#  '♻️washed': 57638,
#  'luseta': 50969,
#  'notp': 218594,
#  'fugel': 96479,
#  'ekg': 35772,
#  'carrots': 17872,
#  'finis': 65139,
#  '☆☆green': 148902,
#  'ribbed': 1947,
#  'tᗯo': 249773,
#  '•finest': 161109,
#  'randomly❤✨': 196666,
#  'roux': 55533,
#  'bobcat': 43234,
#  'wrif': 94294,
#  'unico': 207374,
#  '“pugsly”': 116643,
#  's▪️as': 160800,
#  'landscapes': 56465,
#  'trimming': 7489,
#  'dauchund': 246741,
#  'proscriptive': 122661,
#  '♡♥♡': 164695,
#  '❤black': 51020,
#  'hyvent™': 88456,
#  'mikka': 163824,
#  'discoveries': 34288,
#  'bod': 20168,
#  '11159449': 124094,
#  'nwoti': 176176,
#  "levis's": 87903,
#  'out‼️‼️': 125780,
#  'streatchy': 82341,
#  'pt4': 166265,
#  'creaseproof': 101368,
#  'karoke': 168242,
#  'loa': 20498,
#  'ons': 1005,
#  'clarissa': 34593,
#  'speghetti': 97792,
#  'gefoce': 174894,
#  '●●●●●●✨black': 128813,
#  'dpa': 202559,
#  'soirees': 173758,
#  "'steam": 148674,
#  'no6': 117864,
#  '173750686083': 187268,
#  'smallsize': 174686,
#  'cowler': 76103,
#  'cells\xa0': 18983,
#  'garnier': 4283,
#  'beognia': 100332,
#  'semillas': 79735,
#  'alikes': 23217,
#  'confortabl': 227643,
#  'kristyes': 208909,
#  'domes': 26683,
#  '2800mah': 114438,
#  'multishimmer': 249153,
#  "bow'": 100214,
#  'digdug': 151208,
#  'chiny': 125034,
#  'antwoord': 74400,
#  'diney': 183243,
#  'wireles': 36087,
#  'yp66': 166127,
#  'britt': 21377,
#  'a210s': 151002,
#  'theu': 69029,
#  '71oz': 110406,
#  'snowboarder': 56730,
#  'barbielogo': 182541,
#  "dawson's": 61531,
#  "racks'": 174631,
#  'coachellawear': 201603,
#  'leggin': 21986,
#  'saynotomink': 46274,
#  'ca3155': 123485,
#  '❌corset❌': 176324,
#  'cot': 35429,
#  '719a': 202737,
#  '600camera': 216744,
#  'forceflex': 235657,
#  'seneplex': 29030,
#  'deathstoke': 119885,
#  'boho❤': 48345,
#  'redline': 26629,
#  'oxidation': 18400,
#  'zongs': 174874,
#  'slumerican': 157671,
#  'calsilica': 81921,
#  'madrel': 184959,
#  'greatdeals': 60879,
#  'dehydrated': 13722,
#  'babydoll': 3790,
#  'misstitches': 169461,
#  'backpacking': 13835,
#  '5983': 243250,
#  'bc8635': 182209,
#  'ofalarm': 203376,
#  '4845515': 150874,
#  'rhamnose': 75331,
#  'iclickers': 63800,
#  'reasearched': 197150,
#  'lexi820': 80385,
#  'shervella': 230631,
#  "deadman's": 174781,
#  'pigy': 179165,
#  'bowman': 6269,
#  '43lb': 125866,
#  'sit': 4001,
#  '•reason': 101588,
#  'moriarty': 32472,
#  'handcrafting': 72931,
#  'eyeball': 21809,
#  'couponing': 31780,
#  'ᴍᴇʀᴄʜ': 111490,
#  '24x28': 132515,
#  "attache'": 96841,
#  'removedark': 102002,
#  'jeggings': 1848,
#  'promaster': 75028,
#  'dollar': 3079,
#  'importer': 105803,
#  'hospitality': 28366,
#  'bonnaroo': 55249,
#  'essentials♥️': 27137,
#  '❗️happy': 78603,
#  'kipling': 8685,
#  'leander': 94516,
#  'wiiu': 12037,
#  "✅✅✅✅i'd": 58672,
#  '\xa0slip': 88187,
#  'veggetti': 48883,
#  'shortshorts': 37825,
#  "yummibear's": 99153,
#  'mbps⁴': 205062,
#  "'sarah'": 217262,
#  'ram13': 124214,
#  'name✨': 27024,
#  'wop': 48516,
#  'pcgs': 22853,
#  'skin—it': 102437,
#  'caloah': 223483,
#  'price⛔️': 55404,
#  'edt': 6416,
#  'jennefer': 252227,
#  'jtoner5': 233050,
#  'rodeos': 60406,
#  "'fizzy": 91943,
#  'scurll': 186579,
#  '16ω20mw': 88639,
#  'wtd': 231428,
#  'x250': 135740,
#  "stroker's": 215044,
#  'zaay': 242655,
#  'ikon': 30493,
#  'greattt': 79364,
#  'rooster': 8579,
#  'colder': 7564,
#  'ltiffany': 154924,
#  '358371061222306': 143161,
#  'ᏢᎬᎪᏚᎪnᎢ': 217590,
#  'desgined': 35981,
#  'maleficient': 251414,
#  'shoeschild': 134911,
#  'xuimin': 52986,
#  '12ps': 195900,
#  '•stretch': 31851,
#  '•360°': 122554,
#  '✨try': 57943,
#  'bl\xademishes': 56788,
#  'rrl': 84218,
#  'arras': 76957,
#  '▪mightyfine': 196876,
#  'beaded': 2655,
#  'smartcraft': 197019,
#  'c823': 91923,
#  'mss01': 111031,
#  '✔lean': 66302,
#  'pediatricians': 29805,
#  'forplaycatalogcostume': 122772,
#  'breathemesh': 115055,
#  'k130': 96830,
#  "circle's": 76118,
#  'handl': 83357,
#  'superthickening': 162694,
#  'ᏟᎪᏟᎢi': 112933,
#  'trak': 69837,
#  'creepsville': 153879,
#  'ferrar': 30239,
#  '36gb': 138547,
#  "deposit'": 128171,
#  "zoe's": 62976,
#  'proposition': 74588,
#  'sexydecoration': 168537,
#  '❤️❤️❤️30pairs': 156456,
#  '●listing': 180306,
#  'jaynescloset': 52100,
#  '25inchesw': 172330,
#  'jimmer': 96472,
#  'rulebreakers': 239904,
#  'karlene': 221933,
#  'statement—in': 77886,
#  'unakite': 33336,
#  'leggingstc': 71917,
#  'hottie': 11955,
#  '34723': 104826,
#  'off❗': 89648,
#  'reclusive': 203978,
#  'th0947': 160041,
#  'grided': 78631,
#  'wicket': 38719,
#  'kikikiki': 245347,
#  'subliminal': 80218,
#  '2916': 103564,
#  'kidpai': 72672,
#  'upstage': 154845,
#  'moduloks': 128270,
#  'hindman': 182335,
#  'greenenvy': 54913,
#  'trackpad': 18606,
#  'hparra': 229390,
#  'trotted': 191426,
#  'bd2': 71141,
#  'chalboard': 241695,
#  'ambutler77': 91176,
#  'cyberia': 114636,
#  'vinny': 80939,
#  'fun♡': 87092,
#  'retexturizer': 207118,
#  "charles'": 177065,
#  '35881052691829': 122084,
#  'slime•1': 100668,
#  'cruelty': 3508,
#  'iamkristiig': 120212,
#  'cosmetologist': 24566,
#  'usl': 79342,
#  '○shipped': 69097,
#  '18362': 201684,
#  'absorbant': 39359,
#  'avobenzone': 212685,
#  'kraftrina': 113785,
#  'adhesion': 13432,
#  'tvanderlie': 149607,
#  'bighit': 102145,
#  'pilgrims': 68011,
#  'lunarbeast': 82944,
#  'floragirl': 119147,
#  'skellum1': 230043,
#  'poliwrath': 38385,
#  'superbundledeals': 121522,
#  'newbed': 226133,
#  'augest': 113170,
#  'sound\xa0record': 212593,
#  '001\xa0': 201948,
#  'kayjon': 246569,
#  'mamabear2014': 232088,
#  'navy07': 120949,
#  'skyn': 17687,
#  '5bk': 161830,
#  '•korilakkuma': 157002,
#  '❣mermaid': 85933,
#  "decedent's": 179252,
#  '72x2': 213504,
#  'nawlinurse': 239800,
#  'crichton': 97804,
#  'threated': 127059,
#  'doubloon': 155606,
#  'fl1016': 139763,
#  "volum'exp": 222429,
#  '35hc': 231899,
#  '9780134237510': 188561,
#  'racy': 41797,
#  'bundlestripe': 254223,
#  'gymbory': 127996,
#  '☆☆☆ships': 132059,
#  '•maybellines': 78640,
#  'trippin': 34899,
#  'sydddrich': 235459,
#  'fursona': 182234,
#  'alia': 47900,
#  '❌comes': 208469,
#  'arynaff': 230777,
#  'looooots': 177689,
#  '24x': 28898,
#  '1paris': 100919,
#  'sandrasjewlerybox': 121147,
#  'gatlinburg': 43233,
#  'guy—of': 146434,
#  'gasspasser': 189654,
#  'groboski': 254339,
#  '001g': 94149,
#  'mk9024': 67919,
#  '\xa0xl': 61219,
#  'wl': 31869,
#  'katatouille': 217599,
#  'skomal': 241236,
#  'cildro': 181140,
#  'onward': 80618,
#  'jerryetn73': 201358,
#  'postmaster': 39848,
#  'refugiol': 228121,
#  'flexibility\xa0': 135228,
#  '1305750853': 204267,
#  'setta': 244176,
#  'toujours': 149389,
#  '925stamped': 71980,
#  'bioactive': 55833,
#  'book—the': 139577,
#  '✨✨mac': 235344,
#  '❤️❤️hello': 164050,
#  'wiggles': 22381,
#  '•hdmi': 205158,
#  'lunker': 204055,
#  'makenze': 241665,
#  'altalok': 116411,
#  'lhl3b707': 108034,
#  'quantum': 16537,
#  'joys': 32714,
#  'efficiently': 13857,
#  'vonnegut': 80868,
#  '❣️small': 211067,
#  'schik': 189916,
#  'showpo': 18067,
#  'friend，i': 116864,
#  '▪️these': 27436,
#  'me177qt': 232558,
#  'bundle4mirna': 251485,
#  'iknowmybrands': 126012,
#  'multimediacard': 197754,
#  'kaileyj9': 247938,
#  'bundle': 31,
#  'hagwarts': 255050,
#  '✨usually': 169530,
#  'starch': 15983,
#  'grow': 3836,
#  'twistback': 243228,
#  'cheating': 35247,
#  'are1b': 172879,
#  'acoua': 217261,
#  'retractable\xa0': 133867,
#  'ponade': 63551,
#  '⭐️sleeve': 198462,
#  'rml03': 136219,
#  'reviews‼️': 151090,
#  '4y414l': 228416,
#  'calliope': 57164,
#  '❌hold': 52952,
#  'freesa': 206282,
#  'dvpfx810': 165675,
#  'vp': 63326,
#  'madcat': 128051,
#  'dungreon': 183719,
#  'diviners': 50211,
#  '12x8': 35033,
#  'bum': 5814,
#  'clea': 42194,
#  "motif'": 128591,
#  'doghaus': 187907,
#  'carefuteful': 138384,
#  'slime¡': 246790,
#  'narturo': 233682,
#  'chromatography': 145323,
#  'chopper': 9608,
#  "infant's": 36322,
#  'parmesean': 156615,
#  'cast': 4274,
#  "ariana's": 73469,
#  'inexpensively': 68167,
#  'muticolored': 100261,
#  'bbaile22': 218931,
#  'wanderlust': 12508,
#  '•9x12': 104427,
#  'peltier': 128984,
#  '•reliable': 65784,
#  "cruis'n": 60131,
#  'overfilled': 19856,
#  'tactile': 14533,
#  'terabytes': 109495,
#  'rosematic': 124380,
#  's❤️': 74399,
#  'faceblock': 116021,
#  'w10″': 178001,
#  'stellarina': 251901,
#  'dilly': 66387,
#  "xando's": 213326,
#  'rowley': 11274,
#  'vases': 7246,
#  'drinkup': 207855,
#  'masterpieces': 25050,
#  'lx10': 44207,
#  'briannamorae': 93386,
#  "5'3": 4133,
#  'brightwninf': 129660,
#  'gamerbabe': 218772,
#  'christiandior': 138877,
#  '❤️siberian': 129837,
#  'waaaaaaay': 177910,
#  'wwjd': 85484,
#  'alienware': 20299,
#  '“the': 27303,
#  '12millimeters': 142209,
#  'entiry': 156887,
#  'talsan': 85116,
#  "guest's": 207890,
#  'noél': 193613,
#  'territorial': 150332,
#  'sd3151': 100064,
#  'ontuesday': 195416,
#  'b21': 160514,
#  'flused': 87450,
#  'name': 974,
#  'hollows': 25354,
#  'modbe': 85580,
#  'stampin': 9035,
#  '7970': 197673,
#  'louon': 198993,
#  'climalite': 8234,
#  'dunner': 26605,
#  'nosegay': 89507,
#  'stancey': 246294,
#  'isnthe': 154789,
#  'teabags': 50735,
#  '29427': 170568,
#  'photos‼️': 88864,
#  'mameshiba': 107731,
#  'arenew': 166115,
#  'certifies': 105004,
#  'clogs': 2779,
#  'please\u200b': 135057,
#  '❌please': 10098,
#  'solaris': 43410,
#  'or02': 121812,
#  'maquicomplet': 134507,
#  's570': 112302,
#  'espionage': 61482,
#  'momoberry': 192384,
#  '8700': 66287,
#  '3xsmall': 249649,
#  'inventory\xa0': 58431,
#  '•size✨': 148319,
#  'leopardprint': 55779,
#  "hogwart's": 111879,
#  'nicbro': 72343,
#  'a1378': 63323,
#  '13x10x4': 98794,
#  'habibi': 96119,
#  'massimo': 21331,
#  'ash110883': 255057,
#  'spirtz': 215846,
#  '⚠money': 19186,
#  'suicidal': 38365,
#  'nanoblock': 105862,
#  'flyknit‼️': 231219,
#  'thing”': 176565,
#  "jazmin's": 254276,
#  '\xa0bronze': 55037,
#  'zolciak': 96167,
#  'bertha': 30327,
#  '⚜we': 213439,
#  '4•lululemon': 240851,
#  'aggiekatiebeth': 231498,
#  'likes': 6658,
#  'teletubbies': 26941,
#  'steelemyheart': 219080,
#  'ship☄': 225003,
#  "bat's": 85733,
#  'portssoft': 87507,
#  'nds': 20945,
#  'aliana': 241851,
#  'shapebra': 215905,
#  'lotm': 157574,
#  '1×film': 157823,
#  '♀': 94711,
#  '7884': 198381,
#  'ramons': 236444,
#  'bullies': 18685,
#  'eyelinerbrow': 204630,
#  'deeny': 77499,
#  'vermeer': 17221,
#  '•mount': 137478,
#  'posur': 86004,
#  'dotti': 177928,
#  'underbra': 79189,
#  'crispness': 59123,
#  '156': 24232,
#  'condition✨': 30968,
#  's1826': 98114,
#  '•red\xa0': 170176,
#  'dibutyl': 29023,
#  'glycoloc': 139236,
#  'eyeshadading': 58518,
#  'byham': 185076,
#  'wslot4sim': 72012,
#  'rackets': 26507,
#  'penkiejenny': 224250,
#  '•38c': 136573,
#  '•usa': 26309,
#  '10hrs': 44105,
#  '⚠️found': 135179,
#  'adorem': 227127,
#  'unstick': 203812,
#  'diagnostic': 28437,
#  'je5689b2r': 137306,
#  'nona': 29779,
#  'prsn': 158425,
#  'please•this': 158291,
#  'ehy': 136147,
#  'formals': 27966,
#  '29inch': 51043,
#  'garnamals': 151854,
#  'annmarydc': 206437,
#  '90\xa0': 144039,
#  'emmyisaacs': 232611,
#  'naked5': 45640,
#  'poisonberry': 50996,
#  'ask‼': 207313,
#  'sunye': 227110,
#  '❤❤❤ring': 88893,
#  'crysral': 105855,
#  'soiled': 13779,
#  '☆extends': 185670,
#  'crystaldrusy': 243093,
#  'shin': 9217,
#  'adater’s': 206078,
#  'neeeww': 241319,
#  'deep⭐⭐⭐': 207028,
#  '⭐️condition': 75796,
#  "'quack": 165750,
#  '1018': 35059,
#  'utilise': 212461,
#  'rushes': 34071,
#  'networkbluetooth': 135079,
#  "buckle's": 73800,
#  'ibwellington': 202107,
#  'eyelit': 46445,
#  'gracio': 121030,
#  'chusions': 242253,
#  'bag▪': 200160,
#  'slayy': 176480,
#  "‼️men's": 86459,
#  '✔️purchase': 47258,
#  'hodges': 51571,
#  'specialised': 145162,
#  'hanndle': 183467,
#  'babyset': 196493,
#  'symmentary': 232597,
#  'ct14': 177635,
#  'mrsmullins15': 182700,
#  'fortina': 214439,
#  "•collector's": 98649,
#  'heartworks': 177456,
#  '✨3for5': 218615,
#  'ca3102': 180574,
#  'occupying': 69753,
#  'flops': 1971,
#  'freaking': 16268,
#  'sale⚡️brandymelville': 230012,
#  'presiona': 76375,
#  '0875421288': 204823,
#  '26r': 22166,
#  '⚡️pink⚡️': 247528,
#  'casings': 28880,
#  'glamourous': 42368,
#  '172g\xa0': 104630,
#  'amberlynn': 216258,
#  'pashli': 45071,
#  'ᑭᖇiᑕe': 192083,
#  'lockble': 226353,
#  'xeriscape': 59136,
#  '➖➖best': 27814,
#  'p0urchase': 156888,
#  'selenaly': 189102,
#  'calia™': 194298,
#  'antigua': 19941,
#  '❤❤pipe': 78474,
#  'dawn': 4124,
#  'guster': 116370,
#  'bic©': 122874,
#  '♡soy': 185794,
#  'tauni19': 220857,
#  'haileyjbeis': 93757,
#  'anthony\xa0': 128283,
#  'pathologist': 244628,
#  '•burning': 186371,
#  '⚡️⚡️shockproof': 77390,
#  'waterdrench': 98036,
#  '2856': 86991,
#  'shortened': 15419,
#  'manifesto': 23569,
#  '❤️mini❤️portable': 223329,
#  '⭐️leopard': 159190,
#  'singlesnest': 120848,
#  'techskin': 22550,
#  'kattee': 108189,
#  'double\u200b': 251533,
#  'piana': 114201,
#  'basmati': 73583,
#  "yolanda's": 115782,
#  'abajo': 63224,
#  "'jagger'": 245549,
#  'toetype': 115064,
#  'trisomy': 134076,
#  '88n51k': 200675,
#  '862': 115176,
#  '❎upon': 27808,
#  'kerrang': 48859,
#  'molder': 57532,
#  'workouttank': 89287,
#  '1hard': 46001,
#  'borrowing': 63702,
#  'mèrc': 174838,
#  'michellem33': 158163,
#  'layup': 223460,
#  'washcloth': 16629,
#  'in\xa0this': 98632,
#  'shd': 66308,
#  'artsandcraftshat': 164248,
#  '20019': 251075,
#  '6554': 223036,
#  'pr’s': 147856,
#  '712129': 140747,
#  'tax⛔️this': 166538,
#  "bostonian's": 203435,
#  'sun': 1088,
#  'fashionlover017': 252063,
#  '☆alex0625☆2': 254377,
#  'revitalize\xa0': 161737,
#  'ordoñez': 169005,
#  '4hawthorn': 232545,
#  'v360': 60319,
#  '074900422248': 170309,
#  '60000': 150419,
#  'hrvatski': 211233,
#  'androidd': 217825,
#  'faces': 6603,
#  'contrastingback': 131110,
#  'mimil23': 90573,
#  '•preserves': 102182,
#  'blingedoutbeauty': 37913,
#  'multiliner': 59466,
#  'jebbie': 92188,
#  'franck': 69588,
#  'hfa': 61855,
#  'ring⚡': 23960,
#  'hallows': 13222,
#  'rachelxoxo': 230328,
#  'wodabbe': 111844,
#  'weejuns': 120276,
#  'altuve': 36241,
#  '358318060203407': 144353,
#  'trishula': 69695,
#  'b1978': 225842,
#  'carelessness': 44248,
#  'xi1': 229276,
#  'bellyxray': 242268,
#  'ordinal': 160080,
#  'removeable': 13463,
#  'necklace•': 91984,
#  'simplemoblie': 224472,
#  'lipstickqueen': 188507,
#  'crocheters': 65527,
#  'resistibility': 136524,
#  'fashems': 42486,
#  'veins': 13647,
#  'highlighter⭐️': 239208,
#  'walcase': 159251,
#  'intstant': 97612,
#  'splish': 58392,
#  'hatha': 38617,
#  'amnesiac': 156504,
#  '❤smells': 113609,
#  'tgi': 74308,
#  'watch❗️reserved❗️': 224330,
#  "nicki's": 34251,
#  'cleansed': 7835,
#  'lipidic': 111129,
#  'cammie': 69160,
#  'elaineperez': 118016,
#  'cranberyy': 229550,
#  '×more': 169947,
#  'krisp': 118519,
#  '✅100pcs': 126490,
#  '336': 38581,
#  '34b⚡️sale': 221571,
#  'shoet': 222423,
#  'klogs': 32966,
#  'wetzone': 106221,
#  'hands•••••': 65405,
#  'doorstops': 121185,
#  'b20': 56822,
#  'quiz™': 190441,
#  "also's": 176033,
#  'poshpua': 59654,
#  'dragonvein': 118821,
#  'system—ipad': 205060,
#  'ussr': 96711,
#  'taklon': 15202,
#  'underliners': 114470,
#  'croton': 53918,
#  'reloader': 95906,
#  'lipless': 174106,
#  "'rolling'": 141324,
#  'swipe': 8144,
#  'famous⛥': 174125,
#  'jessicaaftergut': 242120,
#  '3173': 210195,
#  'f76': 205621,
#  "ones'": 146574,
#  "'iconic'": 230547,
#  'atvpdkikx0der': 195894,
#  'metric': 22863,
#  'cs220os': 172665,
#  'kadyt123': 234830,
#  'techpack': 243631,
#  "☆levi's": 245562,
#  'circuitry': 38554,
#  'snehms': 236146,
#  '‼‼‼‼': 144523,
#  'conn': 120996,
#  '❌still': 145357,
#  'fernando': 44439,
#  'elagant': 189036,
#  '19w': 94832,
#  'jlo': 15465,
#  'maclaine': 107576,
#  '¡¡¡¡¡¡please': 179971,
#  '“all': 64076,
#  "19'h": 152093,
#  'n°93': 175340,
#  ...}

# %%
train.head(3)
# Out:
#    train_id                              name  item_condition_id  \
# 1         1  Razer BlackWidow Chroma Keyboard                  3
# 2         2                    AVA-VIV Blouse                  1
# 3         3             Leather Horse Statues                  1
#
#                                         category_name  price  shipping  \
# 1  Electronics/Computers & Tablets/Components & Parts   52.0         0
# 2                         Women/Tops & Blouses/Blouse   10.0         1
# 3                  Home/Home Décor/Home Décor Accents   35.0         1
#
#                                                                                                                                                                                item_description  \
# 1  This keyboard is in great condition and works like it came out of the box. All of the ports are tested and work perfectly. The lights are customizable via the Razer Synapse app on your PC.
# 2                                                                  Adorable top with a hint of lace and a key hole in the back! The pale pink is a 1X, and I also have a 3X available in white!
# 3                 New with tags. Leather horses. Retail for [rm] each. Stand about a foot high. They are being sold as a pair. Any questions please ask. Free shipping. Just got out of storage
#
#      target  category  brand            seq_category_name  \
# 1  3.970292        86   3889   [64, 948, 850, 3361, 1384]
# 2  2.397895      1277   4588             [3, 48, 82, 289]
# 3  3.583519       503   5265  [38, 38, 208, 38, 208, 538]
#
#                                                                                                                                                   seq_item_description  \
# 1  [32, 2755, 11, 8, 50, 17, 1, 253, 65, 21, 1207, 80, 12, 2, 72, 42, 12, 2, 3279, 27, 846, 1, 442, 808, 2, 1319, 27, 7799, 1375, 2, 10964, 56418, 1756, 14, 62, 1095]
# 2                                            [693, 73, 10, 5, 5441, 12, 243, 1, 5, 993, 1393, 8, 2, 130, 2, 2057, 28, 11, 5, 797, 1, 15, 191, 54, 5, 1243, 218, 8, 76]
# 3                    [6, 10, 78, 224, 6637, 279, 4, 22, 205, 1190, 266, 5, 1689, 164, 131, 27, 920, 379, 69, 5, 274, 109, 210, 67, 171, 13, 19, 105, 551, 80, 12, 597]
#
#                       seq_name
# 1  [10964, 25487, 16578, 2755]
# 2           [7741, 10738, 289]
# 3             [224, 2745, 657]

# %%
#EXTRACT DEVELOPTMENT TEST
from sklearn.model_selection import train_test_split
dtrain, dvalid = train_test_split(train, random_state=666, test_size=0.0338)
print(dtrain.shape)
print(dvalid.shape)
# Out:
# (1352724, 13)
# (47322, 13)

# %%
#EMBEDDINGS MAX VALUE
#Base on the histograms, we select the next lengths
MAX_NAME_SEQ = 20 #17
MAX_ITEM_DESC_SEQ = 60 #269
MAX_CATEGORY_NAME_SEQ = 20 #8
MAX_TEXT = np.max([np.max(train.seq_name.max())
                   , np.max(test.seq_name.max())
                   , np.max(train.seq_category_name.max())
                   , np.max(test.seq_category_name.max())
                   , np.max(train.seq_item_description.max())
                   , np.max(test.seq_item_description.max())])+2
MAX_CATEGORY = np.max([train.category.max(), test.category.max()])+1
MAX_BRAND = np.max([train.brand.max(), test.brand.max()])+1
MAX_CONDITION = np.max([train.item_condition_id.max(), 
                        test.item_condition_id.max()])+1

print('[{}] Finished EMBEDDINGS MAX VALUE...'.format(time.time() - start_time))
# Out:
# [283.5490651130676] Finished EMBEDDINGS MAX VALUE...

# %%
#KERAS DATA DEFINITION
from keras.preprocessing.sequence import pad_sequences

def get_keras_data(dataset):
    X = {
        'name': pad_sequences(dataset.seq_name, maxlen=MAX_NAME_SEQ)
        ,'item_desc': pad_sequences(dataset.seq_item_description
                                    , maxlen=MAX_ITEM_DESC_SEQ)
        ,'brand': np.array(dataset.brand)
        ,'category': np.array(dataset.category)
        ,'category_name': pad_sequences(dataset.seq_category_name
                                        , maxlen=MAX_CATEGORY_NAME_SEQ)
        ,'item_condition': np.array(dataset.item_condition_id)
        ,'num_vars': np.array(dataset[["shipping"]])
    }
    return X

X_train = get_keras_data(dtrain)
X_valid = get_keras_data(dvalid)
X_test = get_keras_data(test)

print('[{}] Finished DATA PREPARARTION...'.format(time.time() - start_time))
# Out:
# [331.73213505744934] Finished DATA PREPARARTION...

# %%
X_train
# Out:
# {'brand': array([ 519, 5265, 5265, ..., 3255, 5265, 5265]),
#  'category': array([  35,  752,  711, ..., 1155,  863,  724]),
#  'category_name': array([[   0,    0,    0, ...,  133,  137,  135],
#         [   0,    0,    0, ...,  327,  235, 1065],
#         [   0,    0,    0, ...,   37,  139, 2019],
#         ...,
#         [   0,    0,    0, ..., 1122,  415,  154],
#         [   0,    0,    0, ...,   87, 1423,  137],
#         [   0,    0,    0, ...,   46,   57, 1586]], dtype=int32),
#  'item_condition': array([1, 3, 2, ..., 2, 1, 1]),
#  'item_desc': array([[11457,   172,    51, ...,    18,     4,   366],
#         [    0,     0,     0, ...,   636,  1257,   822],
#         [    0,     0,     0, ...,  4183,  2670,   610],
#         ...,
#         [    0,     0,     0, ...,   375,   493,   459],
#         [  968,    55,  3391, ...,  1710,  1201,  1634],
#         [    0,     0,     0, ...,     5, 10464,  1030]], dtype=int32),
#  'name': array([[   0,    0,    0, ...,  135,  137,   31],
#         [   0,    0,    0, ...,  260,  756,   26],
#         [   0,    0,    0, ..., 4183, 1410,  268],
#         ...,
#         [   0,    0,    0, ..., 1284,  375,  493],
#         [   0,    0,    0, ...,  906, 1143,  108],
#         [   0,    0,    0, ..., 4005,   85,  722]], dtype=int32),
#  'num_vars': array([[1],
#         [1],
#         [0],
#         ...,
#         [1],
#         [1],
#         [0]])}

# %%
#KERAS MODEL DEFINITION
from keras.layers import Input, Dropout, Dense, BatchNormalization, \
    Activation, GRU, Embedding, Flatten, LSTM,concatenate
from keras.models import Model
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping#, TensorBoard
from keras import backend as K
from keras import optimizers
from keras import initializers
import tensorflow as tf

def rmsle(y, y_pred):
    import math
    assert len(y) == len(y_pred)
    to_sum = [(math.log(y_pred[i] + 1) - math.log(y[i] + 1)) ** 2.0 \
              for i, pred in enumerate(y_pred)]
    return (sum(to_sum) * (1.0/len(y))) ** 0.5

def rmsle_tf(y, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y)))

# %%
dr = 0.25

def get_model():
    #params
    dr_r = dr
    
    #Inputs
    name = Input(shape=[X_train["name"].shape[1]], name="name")
    item_desc = Input(shape=[X_train["item_desc"].shape[1]], name="item_desc")
    brand = Input(shape=[1], name="brand")
    category = Input(shape=[1], name="category")
    category_name = Input(shape=[X_train["category_name"].shape[1]], 
                          name="category_name")
    item_condition = Input(shape=[1], name="item_condition")
    num_vars = Input(shape=[X_train["num_vars"].shape[1]], name="num_vars")
    
    #Embeddings layers
    emb_size = 60
    
    emb_name = Embedding(MAX_TEXT, emb_size//3)(name)
    emb_item_desc = Embedding(MAX_TEXT, emb_size)(item_desc)
    emb_category_name = Embedding(MAX_TEXT, emb_size//3)(category_name)
    emb_brand = Embedding(MAX_BRAND, 10)(brand)
    emb_category = Embedding(MAX_CATEGORY, 10)(category)
    emb_item_condition = Embedding(MAX_CONDITION, 5)(item_condition)
    
    rnn_layer1 = GRU(16) (emb_item_desc)
    rnn_layer2 = GRU(8) (emb_category_name)
    rnn_layer3 = GRU(4) (emb_name)
    
    #main layer
    main_l = concatenate([
       Flatten() (emb_brand)
        , Flatten() (emb_category)
        , Flatten() (emb_item_condition)
        , rnn_layer1
        , rnn_layer2
        , rnn_layer3
        , num_vars])
    

    
    main_l = Dropout(0.1)(Dense(512,activation='relu') (main_l))
    main_l = Dropout(0.1)(Dense(64,activation='relu') (main_l))
    
    #output
    output = Dense(1,activation="linear") (main_l)
    
    #model
    model = Model([name, item_desc, brand
                   , category, category_name
                   , item_condition, num_vars], output)
    #optimizer = optimizers.RMSprop()
    optimizer = optimizers.Adam()
    model.compile(loss=rmsle_tf,#"mean_squared_logarithmic_error", 
                  optimizer=optimizer)
    return model

def eval_model(model):
    val_preds = model.predict(X_valid)
    val_preds = np.expm1(val_preds)
    
    y_true = np.array(dvalid.price.values)
    y_pred = val_preds[:, 0]
    v_rmsle = rmsle(y_true, y_pred)
    print(" RMSLE error on dev test: "+str(v_rmsle))
    return v_rmsle
#fin_lr=init_lr * (1/(1+decay))**(steps-1)
exp_decay = lambda init, fin, steps: (init/fin)**(1/(steps-1)) - 1

print('[{}] Finished DEFINEING MODEL...'.format(time.time() - start_time))
# Out:
# [331.90818977355957] Finished DEFINEING MODEL...

# %%
gc.collect()
#FITTING THE MODEL
epochs = 30

BATCH_SIZE = 512 * 60

suffix = str(datetime.now().strftime("%Y-%m-%d-%H-%M"))
NAME = "GRU_" + suffix


steps = int(len(X_train['name'])/BATCH_SIZE) * epochs
lr_init, lr_fin = 0.009, 0.006
lr_decay = exp_decay(lr_init, lr_fin, steps)
log_subdir = '_'.join(['ep', str(epochs),
                    'bs', str(BATCH_SIZE),
                    'lrI', str(lr_init),
                    'lrF', str(lr_fin),
                    'dr', str(dr)])

model = get_model()
K.set_value(model.optimizer.lr, lr_init)
K.set_value(model.optimizer.decay, lr_decay)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# brand (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# category (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# item_condition (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# item_desc (InputLayer)          (None, 60)           0
# __________________________________________________________________________________________________
# category_name (InputLayer)      (None, 20)           0
# __________________________________________________________________________________________________
# name (InputLayer)               (None, 20)           0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 1, 10)        52900       brand[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 1, 10)        13110       category[0][0]
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 1, 5)         30          item_condition[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 60, 60)       15339480    item_desc[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 20, 20)       5113160     category_name[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 20, 20)       5113160     name[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           embedding_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 10)           0           embedding_5[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 5)            0           embedding_6[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 16)           3696        embedding_2[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 8)            696         embedding_3[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 4)            300         embedding_1[0][0]
# __________________________________________________________________________________________________
# num_vars (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 54)           0           flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  gru_1[0][0]
#                                                                  gru_2[0][0]
#                                                                  gru_3[0][0]
#                                                                  num_vars[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          28160       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           32832       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            65          dropout_2[0][0]
# ==================================================================================================
# Total params: 25,697,589
# Trainable params: 25,697,589
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping

callback_1 = TensorBoard(log_dir='./logs/logs_{}'.format(NAME), histogram_freq=0,
                         write_graph=False, write_images=False)
callback_2 = EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=1, mode='auto')
callback_3 = ModelCheckpoint("models/model_{}.hdf5".format(NAME), monitor='val_loss',
                             save_best_only=True, verbose=0)

# %%
#BATCH_SIZE = 512 * 60

history = model.fit(X_train, dtrain.target
                    , epochs=epochs
                    , batch_size=BATCH_SIZE
                    #, validation_split=0.033
                    #, callbacks=[TensorBoard('./logs/'+log_subdir)]
                    , validation_data=(X_valid, dvalid.target)
                    , verbose=1
                    , callbacks=[callback_1,callback_2])
print('[{}] Finished FITTING MODEL...'.format(time.time() - start_time))
# Out:
# Train on 1352724 samples, validate on 47322 samples
# Epoch 1/30
# 1352724/1352724 [==============================] - 96s 71us/step - loss: 0.3612 - val_loss: 0.4619
# Epoch 2/30
# 1352724/1352724 [==============================] - 97s 71us/step - loss: 0.3555 - val_loss: 0.4649
# Epoch 3/30
# 1352724/1352724 [==============================] - 97s 71us/step - loss: 0.3507 - val_loss: 0.4669
# Epoch 4/30
# 1352724/1352724 [==============================] - 97s 71us/step - loss: 0.3445 - val_loss: 0.4662
# Epoch 5/30
# 1352724/1352724 [==============================] - 97s 71us/step - loss: 0.3392 - val_loss: 0.4649
# Epoch 6/30
# 1352724/1352724 [==============================] - 97s 71us/step - loss: 0.3357 - val_loss: 0.4657
# Epoch 7/30
# 1352724/1352724 [==============================] - 97s 71us/step - loss: 0.3297 - val_loss: 0.4705
# Epoch 8/30
# 1352724/1352724 [==============================] - 97s 71us/step - loss: 0.3273 - val_loss: 0.4676
# Epoch 9/30
# 1352724/1352724 [==============================] - 97s 71us/step - loss: 0.3208 - val_loss: 0.4684
# Epoch 10/30
#  153600/1352724 [==>...........................] - ETA: 1:25 - loss: 0.3123

# %% [markdown]
# Epoch 12/100
# 1432425/1432425 [==============================] - 104s 72us/step - loss: 0.3812 - val_loss: 0.4553   -  0.44745

# %%
#EVLUEATE THE MODEL ON DEV TEST
v_rmsle = eval_model(model)
print('[{}] Finished predicting valid set...'.format(time.time() - start_time))

v_rmsle

# %%
#CREATE PREDICTIONS
preds = model.predict(X_test, batch_size=BATCH_SIZE)
preds = np.expm1(preds)
print('[{}] Finished predicting test set...'.format(time.time() - start_time))
submission = test[["test_id"]][:test_len]
submission["price"] = preds[:test_len]
submission.to_csv("./myNN"+log_subdir+"_{:.6}.csv".format(v_rmsle), index=False)
print('[{}] Finished submission...'.format(time.time() - start_time))
